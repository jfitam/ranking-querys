# %% [markdown]
# #### Loading
# Load the required libraries and the files of the dataset.

# %%
# load libraries
from sklearn.datasets import load_svmlight_file
import lightgbm as lgb
from os import path
import numpy as np
import warnings
from ndcg import ndcg_scores_set

# %%
# load the files with sklearn
# Dataset source Microsoft
# https://www.microsoft.com/en-us/research/project/letor-learning-rank-information-retrieval/
# dataset Letor4

Xtr, ytr, qtr = load_svmlight_file(path.join('Data','Fold1', 'train.txt'), query_id=True)
Xva, yva, qva = load_svmlight_file(path.join('Data','Fold1', 'vali.txt'), query_id=True)
Xte, yte, qte = load_svmlight_file(path.join('Data','Fold1', 'test.txt'), query_id=True)

print("Train:", Xtr.shape, "Valid:", Xva.shape, "Test:", Xte.shape)
print("Relevances:", set(ytr))
# Out:
# Train: (9630, 46) Valid: (2707, 46) Test: (2874, 46)
# Relevances: {np.float64(0.0), np.float64(1.0), np.float64(2.0)}

# %% [markdown]
# #### Calculate the frequency for each query in the dataset

# %%
def get_qid_freq(qids):
    '''Look for the amount of entries in each qid
    
    Args:
        qids (narray): list of qids that each observation belongs
        
    Returns:
        A pair of lists, with the qids in order and the amount of appearances in the list
    '''
  
    uniq, first_idx, counts = np.unique(qids, return_index=True, return_counts=True)
    order = np.argsort(first_idx)
    sizes2 = counts[order]
    qids2  = uniq[order]

    return qids2, sizes2

# %%
# create the groups for LightGBM
_ , gtr = get_qid_freq(qtr)
_ , gva = get_qid_freq(qva)
_ , gte = get_qid_freq(qte)

# %%
# sanity checks
print("n_train:", Xtr.shape[0], "sum(gtr):", int(gtr.sum()), "n_groups:", len(gtr))
print("n_valid:", Xva.shape[0], "sum(gva):", int(gva.sum()), "n_groups:", len(gva))
assert gtr.sum() == Xtr.shape[0] and gva.sum() == Xva.shape[0]
# Out:
# n_train: 9630 sum(gtr): 9630 n_groups: 471
# n_valid: 2707 sum(gva): 2707 n_groups: 157

# %% [markdown]
# #### First training

# %%
ranker = lgb.LGBMRanker()
ranker.fit(Xtr, ytr, group=gtr,
           eval_set=[(Xva, yva)], eval_group=[gva],
           eval_at=[1,3,5,10], 
           # early_stopping_rounds=100, 
           # verbose=50,
          )
# Out:
# LGBMRanker()

# %%
# predictions
val_scores  = ranker.predict(Xva)

scores, n = ndcg_scores_set(val_scores, yva, gva)
print("First result: ", sum(scores) / n)
# Out:
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# First result:  0.7470129029463155

# %% [markdown]
# #### Grid search
# Performs grid search to tune the hyperparameters using the validation set

# %%
k = 5
it = 1
best_it = None
best_score = 0
best_model = None
best_params = None
for learning_rate in np.linspace(0.01, 0.1, num=k):
    for num_leaves in np.linspace(31, 12, num=k, dtype=int):  
        for n_estimators in np.linspace(100, 1000, num=k, dtype=int):
                for max_depth in np.linspace(10, 50, num=k, dtype=int):
                    for min_child_samples in np.linspace(10, 50, num=k, dtype=int):
                        # fit
                        ranker = lgb.LGBMRanker(
                            objective="lambdarank",
                            n_estimators=n_estimators,
                            learning_rate=learning_rate,
                            num_leaves=num_leaves,
                            max_depth=max_depth,
                            min_child_samples=min_child_samples,
                            min_child_weight=1e-3,
                            colsample_bytree=0.9,
                            subsample=0.8,
                            subsample_freq=1,
                            max_bin=511,
                            label_gain=[0,1,2],
                            verbosity=-1
                        )
                        ranker.fit(Xtr, ytr, group=gtr,
                                   eval_set=[(Xva, yva)], eval_group=[gva],
                                   eval_at=[1,3,5,10], 
                                   # early_stopping_rounds=100, 
                                   # verbose=50,
                                  )
                        
                        # predictions
                        val_scores  = ranker.predict(Xva)

                        # evaluation
                        scores, n = ndcg_scores_set(val_scores, yva, gva)
                        current_score = sum(scores) / n
                        print(f"Trial number: {it}, ndcg score: {current_score}")
                        if current_score > best_score:
                            print("Saving trial information as best score.")
                            best_score = current_score
                            best_model = ranker
                            best_it = it
                        else:
                            print("Best trial so far: ", best_it)

                        #next
                        it += 1
# Out:
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 1, ndcg score: 0.7523501322558431
# Saving trial information as best score.
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 2, ndcg score: 0.7503542472976475
# Best trial so far:  1
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3, ndcg score: 0.7463703640881979
# Best trial so far:  1
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 4, ndcg score: 0.7532884108590251
# Saving trial information as best score.
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 5, ndcg score: 0.7493263678939904
# Best trial so far:  4
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 6, ndcg score: 0.7499139855743137
# Best trial so far:  4
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 7, ndcg score: 0.7507057148644449
# Best trial so far:  4
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 8, ndcg score: 0.753744580205664
# Saving trial information as best score.
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 9, ndcg score: 0.7547170099527537
# Saving trial information as best score.
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 10, ndcg score: 0.7425811076138248
# Best trial so far:  9
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 11, ndcg score: 0.7499139855743137
# Best trial so far:  9
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 12, ndcg score: 0.7507057148644449
# Best trial so far:  9
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 13, ndcg score: 0.753744580205664
# Best trial so far:  9
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 14, ndcg score: 0.7547170099527537
# Best trial so far:  9
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 15, ndcg score: 0.7425811076138248
# Best trial so far:  9
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 16, ndcg score: 0.7499139855743137
# Best trial so far:  9
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 17, ndcg score: 0.7507057148644449
# Best trial so far:  9
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 18, ndcg score: 0.753744580205664
# Best trial so far:  9
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 19, ndcg score: 0.7547170099527537
# Best trial so far:  9
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 20, ndcg score: 0.7425811076138248
# Best trial so far:  9
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 21, ndcg score: 0.7499139855743137
# Best trial so far:  9
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 22, ndcg score: 0.7507057148644449
# Best trial so far:  9
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 23, ndcg score: 0.753744580205664
# Best trial so far:  9
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 24, ndcg score: 0.7547170099527537
# Best trial so far:  9
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 25, ndcg score: 0.7425811076138248
# Best trial so far:  9
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 26, ndcg score: 0.7439310182542684
# Best trial so far:  9
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 27, ndcg score: 0.7538716856945513
# Best trial so far:  9
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 28, ndcg score: 0.7430965106075191
# Best trial so far:  9
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 29, ndcg score: 0.7464103670620782
# Best trial so far:  9
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 30, ndcg score: 0.7522461234410067
# Best trial so far:  9
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 31, ndcg score: 0.7489429932312919
# Best trial so far:  9
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 32, ndcg score: 0.7502016027002139
# Best trial so far:  9
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 33, ndcg score: 0.7481257082612081
# Best trial so far:  9
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 34, ndcg score: 0.7618434565832763
# Saving trial information as best score.
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 35, ndcg score: 0.7453612586333905
# Best trial so far:  34
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 36, ndcg score: 0.7489429932312919
# Best trial so far:  34
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 37, ndcg score: 0.7502016027002139
# Best trial so far:  34
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 38, ndcg score: 0.7481257082612081
# Best trial so far:  34
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 39, ndcg score: 0.7606956122640742
# Best trial so far:  34
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 40, ndcg score: 0.7453612586333905
# Best trial so far:  34
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 41, ndcg score: 0.7489429932312919
# Best trial so far:  34
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 42, ndcg score: 0.7502016027002139
# Best trial so far:  34
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 43, ndcg score: 0.7481257082612081
# Best trial so far:  34
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 44, ndcg score: 0.7606956122640742
# Best trial so far:  34
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 45, ndcg score: 0.7453612586333905
# Best trial so far:  34
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 46, ndcg score: 0.7489429932312919
# Best trial so far:  34
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number:
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3086, ndcg score: 0.7483492990001357
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3087, ndcg score: 0.7365211759302057
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3088, ndcg score: 0.7474288947762637
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3089, ndcg score: 0.7407181118505864
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3090, ndcg score: 0.7368116705704116
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3091, ndcg score: 0.7483492990001357
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3092, ndcg score: 0.7365211759302057
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3093, ndcg score: 0.7474288947762637
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3094, ndcg score: 0.7407181118505864
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3095, ndcg score: 0.7368116705704116
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3096, ndcg score: 0.7483492990001357
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3097, ndcg score: 0.7365211759302057
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3098, ndcg score: 0.7474288947762637
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3099, ndcg score: 0.7407181118505864
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3100, ndcg score: 0.7368116705704116
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3101, ndcg score: 0.748795583154154
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3102, ndcg score: 0.7511245304471357
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3103, ndcg score: 0.749868522600332
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3104, ndcg score: 0.7309109174056617
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3105, ndcg score: 0.7371389807824897
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3106, ndcg score: 0.748795583154154
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3107, ndcg score: 0.7338147029279728
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3108, ndcg score: 0.749868522600332
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3109, ndcg score: 0.7504442972689886
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3110, ndcg score: 0.7371389807824897
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3111, ndcg score: 0.748795583154154
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3112, ndcg score: 0.7338147029279728
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3113, ndcg score: 0.749868522600332
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3114, ndcg score: 0.7504442972689886
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3115, ndcg score: 0.7371389807824897
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3116, ndcg score: 0.748795583154154
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3117, ndcg score: 0.7338147029279728
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3118, ndcg score: 0.749868522600332
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3119, ndcg score: 0.7504442972689886
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3120, ndcg score: 0.7371389807824897
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3121, ndcg score: 0.748795583154154
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3122, ndcg score: 0.7338147029279728
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3123, ndcg score: 0.749868522600332
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3124, ndcg score: 0.7504442972689886
# Best trial so far:  1255
# C:\Users\jfita\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning:
#
# X does not have valid feature names, but LGBMRanker was fitted with feature names
# Trial number: 3125, ndcg score: 0.7371389807824897
# Best trial so far:  1255

# %% [markdown]
# ### Test
# Use the best model found with the test set

# %%
# predictions
test_scores = best_model.predict(Xte)

# evaluation
scores, n = ndcg_scores_set(test_scores, yte, gte)
current_score = sum(scores) / n
print("The final score of the model with the test set is ", current_score, "\n")
print("Parameters used: ", "\n")
print(best_model)
# Out:
# The final score of the model with the test set is  0.7452134863924014
#
# Parameters used:
#
# LGBMRanker(colsample_bytree=0.9, label_gain=[0, 1, 2],
#            learning_rate=np.float64(0.05500000000000001), max_bin=511,
#            max_depth=np.int64(10), min_child_samples=np.int64(50),
#            n_estimators=np.int64(100), num_leaves=np.int64(31),
#            objective='lambdarank', subsample=0.8, subsample_freq=1,
#            verbosity=-1)

# %%
best_model
# Out:
# LGBMRanker(colsample_bytree=0.9, label_gain=[0, 1, 2],
#            learning_rate=np.float64(0.05500000000000001), max_bin=511,
#            max_depth=np.int64(10), min_child_samples=np.int64(50),
#            n_estimators=np.int64(100), num_leaves=np.int64(31),
#            objective='lambdarank', subsample=0.8, subsample_freq=1,
#            verbosity=-1)

# %%
import plotly.express as px

fig = px.histogram(scores, nbins=20)
fig.update_layout(title="NDCG score per query", xaxis_title="# queries", yaxis_title="NDCG Value", showlegend=False)

fig.show()
